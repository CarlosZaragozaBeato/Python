# %%
import polars as pl

s = pl.Series("a", [1, 2, 3, 4, 5])
print(s)
# Out:
# shape: (5,)
# Series: 'a' [i64]
# [
# 	1
# 	2
# 	3
# 	4
# 	5
# ]

# %%
from datetime import datetime

df = pl.DataFrame(
    {
        "integer": [1, 2, 3, 4, 5],
        "date": [
            datetime(2022, 1, 1),
            datetime(2022, 1, 2),
            datetime(2022, 1, 3),
            datetime(2022, 1, 4),
            datetime(2022, 1, 5),
        ],
        "float": [4.0, 5.0, 6.0, 7.0, 8.0],
    }
)

print(df)
# Out:
# shape: (5, 3)
# ┌─────────┬─────────────────────┬───────┐
# │ integer ┆ date                ┆ float │
# │ ---     ┆ ---                 ┆ ---   │
# │ i64     ┆ datetime[μs]        ┆ f64   │
# ╞═════════╪═════════════════════╪═══════╡
# │ 1       ┆ 2022-01-01 00:00:00 ┆ 4.0   │
# │ 2       ┆ 2022-01-02 00:00:00 ┆ 5.0   │
# │ 3       ┆ 2022-01-03 00:00:00 ┆ 6.0   │
# │ 4       ┆ 2022-01-04 00:00:00 ┆ 7.0   │
# │ 5       ┆ 2022-01-05 00:00:00 ┆ 8.0   │
# └─────────┴─────────────────────┴───────┘

# %%
print(df.head(3))
# Out:
# shape: (3, 3)
# ┌─────────┬─────────────────────┬───────┐
# │ integer ┆ date                ┆ float │
# │ ---     ┆ ---                 ┆ ---   │
# │ i64     ┆ datetime[μs]        ┆ f64   │
# ╞═════════╪═════════════════════╪═══════╡
# │ 1       ┆ 2022-01-01 00:00:00 ┆ 4.0   │
# │ 2       ┆ 2022-01-02 00:00:00 ┆ 5.0   │
# │ 3       ┆ 2022-01-03 00:00:00 ┆ 6.0   │
# └─────────┴─────────────────────┴───────┘

# %%
print(df.tail(3))
# Out:
# shape: (3, 3)
# ┌─────────┬─────────────────────┬───────┐
# │ integer ┆ date                ┆ float │
# │ ---     ┆ ---                 ┆ ---   │
# │ i64     ┆ datetime[μs]        ┆ f64   │
# ╞═════════╪═════════════════════╪═══════╡
# │ 3       ┆ 2022-01-03 00:00:00 ┆ 6.0   │
# │ 4       ┆ 2022-01-04 00:00:00 ┆ 7.0   │
# │ 5       ┆ 2022-01-05 00:00:00 ┆ 8.0   │
# └─────────┴─────────────────────┴───────┘

# %%
print(df.sample(3))
# Out:
# shape: (3, 3)
# ┌─────────┬─────────────────────┬───────┐
# │ integer ┆ date                ┆ float │
# │ ---     ┆ ---                 ┆ ---   │
# │ i64     ┆ datetime[μs]        ┆ f64   │
# ╞═════════╪═════════════════════╪═══════╡
# │ 5       ┆ 2022-01-05 00:00:00 ┆ 8.0   │
# │ 2       ┆ 2022-01-02 00:00:00 ┆ 5.0   │
# │ 4       ┆ 2022-01-04 00:00:00 ┆ 7.0   │
# └─────────┴─────────────────────┴───────┘

# %%
print(df.describe())
# Out:
# shape: (9, 4)
# ┌────────────┬──────────┬─────────────────────┬──────────┐
# │ describe   ┆ integer  ┆ date                ┆ float    │
# │ ---        ┆ ---      ┆ ---                 ┆ ---      │
# │ str        ┆ f64      ┆ str                 ┆ f64      │
# ╞════════════╪══════════╪═════════════════════╪══════════╡
# │ count      ┆ 5.0      ┆ 5                   ┆ 5.0      │
# │ null_count ┆ 0.0      ┆ 0                   ┆ 0.0      │
# │ mean       ┆ 3.0      ┆ null                ┆ 6.0      │
# │ std        ┆ 1.581139 ┆ null                ┆ 1.581139 │
# │ min        ┆ 1.0      ┆ 2022-01-01 00:00:00 ┆ 4.0      │
# │ 25%        ┆ 2.0      ┆ null                ┆ 5.0      │
# │ 50%        ┆ 3.0      ┆ null                ┆ 6.0      │
# │ 75%        ┆ 4.0      ┆ null                ┆ 7.0      │
# │ max        ┆ 5.0      ┆ 2022-01-05 00:00:00 ┆ 8.0      │
# └────────────┴──────────┴─────────────────────┴──────────┘

# %%
import numpy as np

df = pl.DataFrame(
    {
        "nrs": [1, 2, 3, None, 5],
        "names": ["foo", "ham", "spam", "egg", None],
        "random": np.random.rand(5),
        "groups": ["A", "A", "B", "C", "B"],
    }
)
print(df)
# Out:
# shape: (5, 4)
# ┌──────┬───────┬──────────┬────────┐
# │ nrs  ┆ names ┆ random   ┆ groups │
# │ ---  ┆ ---   ┆ ---      ┆ ---    │
# │ i64  ┆ str   ┆ f64      ┆ str    │
# ╞══════╪═══════╪══════════╪════════╡
# │ 1    ┆ foo   ┆ 0.024992 ┆ A      │
# │ 2    ┆ ham   ┆ 0.290822 ┆ A      │
# │ 3    ┆ spam  ┆ 0.710458 ┆ B      │
# │ null ┆ egg   ┆ 0.674221 ┆ C      │
# │ 5    ┆ null  ┆ 0.17835  ┆ B      │
# └──────┴───────┴──────────┴────────┘

# %%
out = df.select(
    pl.sum("nrs"),
    pl.col("names").sort(),
    pl.col("names").first().alias("first name"),
    (pl.mean("nrs") * 10).alias("10xnrs")
)
print(out)
# Out:
# shape: (5, 4)
# ┌─────┬───────┬────────────┬────────┐
# │ nrs ┆ names ┆ first name ┆ 10xnrs │
# │ --- ┆ ---   ┆ ---        ┆ ---    │
# │ i64 ┆ str   ┆ str        ┆ f64    │
# ╞═════╪═══════╪════════════╪════════╡
# │ 11  ┆ null  ┆ foo        ┆ 27.5   │
# │ 11  ┆ egg   ┆ foo        ┆ 27.5   │
# │ 11  ┆ foo   ┆ foo        ┆ 27.5   │
# │ 11  ┆ ham   ┆ foo        ┆ 27.5   │
# │ 11  ┆ spam  ┆ foo        ┆ 27.5   │
# └─────┴───────┴────────────┴────────┘

# %%
df = df.with_columns(
  pl.sum("nrs").alias("nrs_sum"),
  pl.col("random").count().alias("count")
)
print(df)
# Out:
# shape: (5, 6)
# ┌──────┬───────┬──────────┬────────┬─────────┬───────┐
# │ nrs  ┆ names ┆ random   ┆ groups ┆ nrs_sum ┆ count │
# │ ---  ┆ ---   ┆ ---      ┆ ---    ┆ ---     ┆ ---   │
# │ i64  ┆ str   ┆ f64      ┆ str    ┆ i64     ┆ u32   │
# ╞══════╪═══════╪══════════╪════════╪═════════╪═══════╡
# │ 1    ┆ foo   ┆ 0.024992 ┆ A      ┆ 11      ┆ 5     │
# │ 2    ┆ ham   ┆ 0.290822 ┆ A      ┆ 11      ┆ 5     │
# │ 3    ┆ spam  ┆ 0.710458 ┆ B      ┆ 11      ┆ 5     │
# │ null ┆ egg   ┆ 0.674221 ┆ C      ┆ 11      ┆ 5     │
# │ 5    ┆ null  ┆ 0.17835  ┆ B      ┆ 11      ┆ 5     │
# └──────┴───────┴──────────┴────────┴─────────┴───────┘

# %%
out = df.filter(pl.col("nrs") > 2)
print(out)
# Out:
# shape: (2, 6)
# ┌─────┬───────┬──────────┬────────┬─────────┬───────┐
# │ nrs ┆ names ┆ random   ┆ groups ┆ nrs_sum ┆ count │
# │ --- ┆ ---   ┆ ---      ┆ ---    ┆ ---     ┆ ---   │
# │ i64 ┆ str   ┆ f64      ┆ str    ┆ i64     ┆ u32   │
# ╞═════╪═══════╪══════════╪════════╪═════════╪═══════╡
# │ 3   ┆ spam  ┆ 0.710458 ┆ B      ┆ 11      ┆ 5     │
# │ 5   ┆ null  ┆ 0.17835  ┆ B      ┆ 11      ┆ 5     │
# └─────┴───────┴──────────┴────────┴─────────┴───────┘

# %%
out = df.group_by("groups").agg(
    pl.sum("nrs"),  # sum nrs by groups
    pl.col("random").count().alias("count"),  # count group members
    # sum random where name != null
    pl.col("random").filter(pl.col("names").is_not_null()).sum().name.suffix("_sum"),
    pl.col("names").reverse().alias("reversed names"),
)
print(out)
# Out:
# shape: (3, 5)
# ┌────────┬─────┬───────┬────────────┬────────────────┐
# │ groups ┆ nrs ┆ count ┆ random_sum ┆ reversed names │
# │ ---    ┆ --- ┆ ---   ┆ ---        ┆ ---            │
# │ str    ┆ i64 ┆ u32   ┆ f64        ┆ list[str]      │
# ╞════════╪═════╪═══════╪════════════╪════════════════╡
# │ B      ┆ 8   ┆ 2     ┆ 0.710458   ┆ [null, "spam"] │
# │ A      ┆ 3   ┆ 2     ┆ 0.315814   ┆ ["ham", "foo"] │
# │ C      ┆ 0   ┆ 1     ┆ 0.674221   ┆ ["egg"]        │
# └────────┴─────┴───────┴────────────┴────────────────┘

# %%
pl.col("foo").sort().head(2)
df.select(pl.col("foo").sort().head(2), pl.col("bar").filter(pl.col("foo") == 1).sum())
# Out:
# <Expr ['col("foo").sort(asc).slice(off…'] at 0x7D1F6721BC10>
